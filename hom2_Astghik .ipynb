# %%
numberlist= input ("Input some numbers seprated by a comma: ")
def avg(numberlist):
    return sum(numberlist) / len(numberlist)
print avg(numberlist)
# Out:
# Input some numbers seprated by a comma: 1,2,3,4,5
# 3.0

# %%
numberlist2= input ("Input some numbers seprated by a comma: ")
occurrances = input ("Inpute the number of occurrences")
def avg(numberlist2):
    return sum(numberlist2[len(numberlist2)-occurrances:])/occurrances
print avg(numberlist2)
# Out:
# Input some numbers seprated by a comma: 1,2,3,4,5
# Inpute the number of occurrences3
# 4.0

# %%
import random

# %%
random.randint(1,100)
# Out:
# 47

# %%
x = 47
if x in range (50,100):
    print ("win")
elif x in range (1,51):
    print("loss")
elif x==100:
    print ("draw")
else:
    print("something is false")
# Out:
# loss

# %%
import pandas_datareader.data as web

# %%
stocks = web.DataReader(["WMT","TM","DIS"],"google")

# %%
stocklist=["WMT","TM","DIS"]
for f in stocklist:
    data=web.DataReader(f,"google")
    print  data.head(7)
# Out:
#              Open   High    Low  Close    Volume
# Date
# 2010-01-04  53.74  54.67  53.67  54.23  20753890
# 2010-01-05  54.09  54.19  53.57  53.69  15649378
# 2010-01-06  53.50  53.83  53.42  53.57  12517828
# 2010-01-07  53.72  53.75  53.26  53.60  10662697
# 2010-01-08  53.43  53.53  53.02  53.33  11363488
# 2010-01-11  53.33  54.44  53.10  54.21  13989639
# 2010-01-12  54.00  54.75  53.86  54.73  15117022
#              Open   High    Low  Close  Volume
# Date
# 2010-01-04  84.75  85.17  84.71  85.08  258831
# 2010-01-05  83.17  83.90  83.01  83.77  466821
# 2010-01-06  84.35  85.07  84.20  84.84  389949
# 2010-01-07  83.11  83.84  83.11  83.79  377635
# 2010-01-08  84.50  85.89  84.50  85.76  351871
# 2010-01-11  86.13  86.50  85.35  86.20  327897
# 2010-01-12  89.43  89.57  88.55  89.50  906695
#              Open   High    Low  Close    Volume
# Date
# 2010-01-04  32.50  32.75  31.87  32.07  13700385
# 2010-01-05  32.07  32.16  31.70  31.99  10307697
# 2010-01-06  31.90  32.00  31.68  31.82  10709499
# 2010-01-07  31.77  31.86  31.54  31.83   8202059
# 2010-01-08  31.66  31.94  31.53  31.88   7657457
# 2010-01-11  31.53  31.74  31.09  31.36  11254030
# 2010-01-12  31.02  31.12  30.68  30.82  14618808

# %%
import matplotlib.pyplot as plt

# %%
stockist=["WMT","DIS","TM"]
for f in stocklist:
    data=plt.plot(web.DataReader(f, 'google')["Close"])
    print(plt.show())
# Out:
# None
# None
# None
